# %%
import pandas as pd
from haversine import haversine, Unit
import time

# %%
# Load the data
properties = pd.read_csv('../data/Airport Distance/bq-unique-property-postcodes.csv')
airports = pd.read_csv('../data/Airport Distance/bq-england-airports.csv')
properties_airports_shortest_distance = properties.copy()

# %%
properties
# Out:
#          Postcode        Lat      Long
# 0         GL8 8HA  51.640620 -2.152272
# 1         SS2 4RJ  51.547842  0.739400
# 2        DA14 6BQ  51.422746  0.099688
# 3         KT6 6HR  51.393117 -0.299780
# 4         ME7 4EB  51.380130  0.557023
# ...           ...        ...       ...
# 1192273  WS13 6SY  52.688117 -1.806688
# 1192274  LE17 6LB  52.454033 -1.057775
# 1192275   CB5 8FS  52.209282  0.136840
# 1192276   HD9 7BE  53.589470 -1.762828
# 1192277  MK45 1GH  52.012143 -0.506868
#
# [1192278 rows x 3 columns]

# %%
# Prepare a dataframe for the distances
distances = pd.DataFrame()

# %%
# Check the range of Lat and Long in properties data
print(properties['Lat'].min(), properties['Lat'].max())
print(properties['Long'].min(), properties['Long'].max())
# Out:
# 49.895171 55.797415
# -6.352647 1.762773

# %%
# Remove any rows with invalid Lat and Long values
# properties = properties[(properties['Lat'] >= -90) & (properties['Lat'] <= 90)]
# properties = properties[(properties['Long'] >= -180) & (properties['Long'] <= 180)]
properties
# Out:
#          Postcode        Lat      Long
# 0         GL8 8HA  51.640620 -2.152272
# 1         SS2 4RJ  51.547842  0.739400
# 2        DA14 6BQ  51.422746  0.099688
# 3         KT6 6HR  51.393117 -0.299780
# 4         ME7 4EB  51.380130  0.557023
# ...           ...        ...       ...
# 1192273  WS13 6SY  52.688117 -1.806688
# 1192274  LE17 6LB  52.454033 -1.057775
# 1192275   CB5 8FS  52.209282  0.136840
# 1192276   HD9 7BE  53.589470 -1.762828
# 1192277  MK45 1GH  52.012143 -0.506868
#
# [1192278 rows x 3 columns]

# %%
# Iterate over each airport
for i, airport in airports.iterrows():
    airport_loc = (airport['Y'], airport['X'])
    # Start timing the operation
    start_time = time.time()
    
    distances[airport['Airport']] = properties.apply(lambda x: haversine((x['Lat'], x['Long']), airport_loc), axis=1)
    
    # Calculate and print the elapsed time
    elapsed_time = time.time() - start_time
    print(f"Elapsed time for {airport['Airport']}: {elapsed_time} seconds")
# Out:
# Elapsed time for Biggin Hill: 4.435509920120239 seconds
# Elapsed time for Birmingham: 4.563212156295776 seconds
# Elapsed time for Blackpool: 4.357810020446777 seconds
# Elapsed time for Bournemouth: 4.330810070037842 seconds
# Elapsed time for Bristol: 4.282088279724121 seconds
# Elapsed time for Cambridge: 4.31036114692688 seconds
# Elapsed time for Carlisle: 4.268824100494385 seconds
# Elapsed time for Coventry: 4.29690408706665 seconds
# Elapsed time for Doncaster Sheffield: 4.280933141708374 seconds
# Elapsed time for Durham Tees Valley: 4.28282618522644 seconds
# Elapsed time for East Midlands International: 4.329210042953491 seconds
# Elapsed time for Exeter: 4.259700059890747 seconds
# Elapsed time for Gatwick: 4.287750720977783 seconds
# Elapsed time for Gloucestershire: 4.25236701965332 seconds
# Elapsed time for Heathrow: 4.2681849002838135 seconds
# Elapsed time for Humberside: 4.278806209564209 seconds
# Elapsed time for Isles Of Scilly (St.Marys): 4.287585020065308 seconds
# Elapsed time for Isles Of Scilly (Tresco): 4.291166067123413 seconds
# Elapsed time for Lands End (St Just): 4.339450120925903 seconds
# Elapsed time for Leeds Bradford: 4.355572938919067 seconds
# Elapsed time for Liverpool (John Lennon): 4.33580207824707 seconds
# Elapsed time for London City: 4.294502019882202 seconds
# Elapsed time for Luton: 4.411436080932617 seconds
# Elapsed time for Lydd: 5.319939136505127 seconds
# Elapsed time for Manchester: 4.302563905715942 seconds
# Elapsed time for Manston (Kent Int): 4.248682975769043 seconds
# Elapsed time for Newcastle: 4.302511215209961 seconds
# Elapsed time for Newquay: 4.299008131027222 seconds
# Elapsed time for Norwich: 4.2479259967803955 seconds
# Elapsed time for Oxford (Kidlington): 4.302951812744141 seconds
# Elapsed time for Penzance Heliport: 4.348443984985352 seconds
# Elapsed time for Plymouth: 4.261209726333618 seconds
# Elapsed time for Shoreham: 4.267155885696411 seconds
# Elapsed time for Southampton: 4.306707859039307 seconds
# Elapsed time for Southend: 4.312772989273071 seconds
# Elapsed time for Stansted: 4.282704830169678 seconds

# %%
# Join the distances to the properties dataframe
properties = pd.concat([properties, distances], axis=1)

# %%
properties
# Out:
#          Postcode        Lat      Long  Biggin Hill  Birmingham   Blackpool  \
# 0         GL8 8HA  51.640620 -2.152272   154.874188   94.493102  245.080798
# 1         SS2 4RJ  51.547842  0.739400    54.787702  197.488756  355.630895
# 2        DA14 6BQ  51.422746  0.099688    11.233875  170.502517  336.994524
# 3         KT6 6HR  51.393117 -0.299780    23.814591  153.862022  323.438784
# 4         ME7 4EB  51.380130  0.557023    37.061823  197.751005  360.793906
# ...           ...        ...       ...          ...         ...         ...
# 1192273  WS13 6SY  52.688117 -1.806688   196.268131   26.558076  146.441736
# 1192274  LE17 6LB  52.454033 -1.057775   145.357837   46.467651  198.007143
# 1192275   CB5 8FS  52.209282  0.136840    97.844004  130.596312  275.093938
# 1192276   HD9 7BE  53.589470 -1.762828   278.820806  126.445194   86.847770
# 1192277  MK45 1GH  52.012143 -0.506868    84.181386   97.410055  259.734474
#
#          Bournemouth     Bristol   Cambridge    Carlisle  ...   Newcastle  \
# 0          98.507519   48.220524  171.611084  369.621915  ...  379.055852
# 1         198.722477  239.867905   83.304269  444.979366  ...  420.405972
# 2         152.789553  195.183500   87.753820  436.531496  ...  419.354196
# 3         127.054922  167.486919   96.552402  428.464147  ...  415.809382
# 4         179.854479  226.958423   96.036252  455.024402  ...  433.457147
# ...              ...         ...         ...         ...  ...         ...
# 1192273   212.439269  157.756844  144.317150  259.044312  ...  261.459749
# 1192274   193.921912  164.496346   87.937534  299.617588  ...  290.399780
# 1192275   209.574160  216.433740    2.507779  360.634134  ...  336.920093
# 1192276   312.693870  253.579441  200.925350  164.954368  ...  161.191158
# 1192277   165.222357  167.363409   51.440620  359.529430  ...  345.519382
#
#             Newquay     Norwich  Oxford (Kidlington)  Penzance Heliport  \
# 0        239.402949  260.409953            61.302675         289.634366
# 1        419.917571  130.037222           145.116586         466.525885
# 2        373.538261  160.337214           107.702747         420.097942
# 3        345.949648  178.282787            85.340913         392.764072
# 4        403.216168  151.620718           138.684438         449.116653
# ...             ...         ...                  ...                ...
# 1192273  332.968600  207.897209           101.108461         383.486415
# 1192274  352.814949  159.639909            71.611974         403.502843
# 1192275  407.193406   92.713704           108.003968         456.775727
# 1192276  413.760758  227.126839           197.962716         462.953328
# 1192277  358.074928  141.543134            59.084166         407.686455
#
#            Plymouth    Shoreham  Southampton    Southend    Stansted
# 0        192.489192  157.614412    94.468688  197.383818  166.796919
# 1        361.607378  107.068842   160.309331    3.444521   51.019732
# 2        315.190168   70.959032   114.291716   44.885251   52.400666
# 3        287.999372   62.221911    88.608391   72.204810   66.223631
# 4        344.002639   84.843790   141.756840   23.376969   60.386087
# ...             ...         ...          ...         ...         ...
# 1192273  297.928405  231.087356   195.557415  211.730238  165.258436
# 1192274  309.361974  187.792409   168.352304  155.584011  108.665863
# 1192275  355.616635  155.809002   173.850256   81.085850   36.616235
# 1192276  386.954450  322.415854   294.625254  279.656124  232.443412
# 1192277  306.811146  131.903548   131.838543   96.722123   52.998859
#
# [1192278 rows x 39 columns]

# %%
properties_airports_shortest_distance['Nearest_Airport_Distance'] = distances.min(axis=1)
properties_airports_shortest_distance['Nearest_Airport'] = distances.idxmin(axis=1)
properties_airports_shortest_distance
# Out:
#          Postcode        Lat      Long  Nearest_Airport_Distance  \
# 0         GL8 8HA  51.640620 -2.152272                 28.157945
# 1         SS2 4RJ  51.547842  0.739400                  3.444521
# 2        DA14 6BQ  51.422746  0.099688                  9.768120
# 3         KT6 6HR  51.393117 -0.299780                 13.706516
# 4         ME7 4EB  51.380130  0.557023                 23.376969
# ...           ...        ...       ...                       ...
# 1192273  WS13 6SY  52.688117 -1.806688                 26.558076
# 1192274  LE17 6LB  52.454033 -1.057775                 30.139959
# 1192275   CB5 8FS  52.209282  0.136840                  2.507779
# 1192276   HD9 7BE  53.589470 -1.762828                 31.673731
# 1192277  MK45 1GH  52.012143 -0.506868                 17.721733
#
#          Nearest_Airport
# 0        Gloucestershire
# 1               Southend
# 2            London City
# 3               Heathrow
# 4               Southend
# ...                  ...
# 1192273       Birmingham
# 1192274         Coventry
# 1192275        Cambridge
# 1192276   Leeds Bradford
# 1192277            Luton
#
# [1192278 rows x 5 columns]

# %%
# Specify the output file path for the merged CSV file
output_file_path = f'properties_airports_shortest_distance.csv'

# Write the merged_data DataFrame to a CSV file
properties_airports_shortest_distance.to_csv(output_file_path)
